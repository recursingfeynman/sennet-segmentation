# %%
import os
from kaggle_secrets import UserSecretsClient

secrets = UserSecretsClient()

GITHUB_TOKEN = secrets.get_secret("github-token")
USERNAME = secrets.get_secret("github-username")
URL = f"https://{USERNAME}:{GITHUB_TOKEN}@github.com/{USERNAME}/sennet-segmentation.git"
    
os.system(f"git clone {URL}")
# Out:
# Cloning into 'sennet-segmentation'...
# 0

# %%
# !pip wheel $(cat sennet-segmentation/requirements.txt | grep -v neptune)
# Out:
# ...
#   Obtaining dependency information for albumentations from https://files.pythonhosted.org/packages/9b/f6/c486cedb4f75147232f32ec4c97026714cfef7c7e247a1f0427bc5489f66/albumentations-1.3.1-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for antspyx from https://files.pythonhosted.org/packages/76/a7/57ef167248da8a52814d405f99961d56003a001c1bef84789260eb6a6d13/antspyx-0.4.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
# ...
#   Obtaining dependency information for connected-components-3d from https://files.pythonhosted.org/packages/03/08/727fd783b361e7ced0ad4196ae93e48f251eb11e18165c7937a94475d26e/connected_components_3d-3.12.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
# ...
#   Obtaining dependency information for segmentation-models-pytorch from https://files.pythonhosted.org/packages/cb/70/4aac1b240b399b108ce58029ae54bc14497e1bbc275dfab8fd3c84c1e35d/segmentation_models_pytorch-0.3.3-py3-none-any.whl.metadata
# ...

# %%
delete = [
    "torch-2", "torchvision", "nvidia", "albumentations", "tqdm", "joblib", "Jinja2", "threadpoolctl",
    "opencv_python_headless", "statsmodels", "scikit_learn", "sympy", "numpy", "pandas",
    "matplotlib", "requests", "tzdata", "mpmath", "PyYAML", "Pillow", "MarkupSafe",
    "networkx", "Pillow", "plotly", "scipy", "qudida", "tenacity", "timm", "python_dateutil",
    "lazy_loader", "six", "webcolors", "scikit_image", "fsspec", "patsy", "timm", "pytz", 
    "urllib3", "typing_extensions", "tifffile", "safetensors", "retrying", "pyparsing",
    "packaging", "kiwisolver", "imageio", "idna", "fonttools", "filelock", "cycler",
    "contourpy", "charset_normalizer", "certifi", "nibabel", "huggingface_hub"
]

for wheel in os.listdir("."):
    if any(subs in wheel for subs in delete):
        print(f"Remove {wheel}")
        os.remove(wheel)
# Out:
# Remove nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl
# Remove python_dateutil-2.8.2-py2.py3-none-any.whl
# Remove nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl
# Remove mpmath-1.3.0-py3-none-any.whl
# Remove albumentations-1.3.1-py3-none-any.whl
# Remove Jinja2-3.1.2-py3-none-any.whl
# Remove scikit_image-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Remove lazy_loader-0.3-py3-none-any.whl
# Remove tenacity-8.2.3-py3-none-any.whl
# Remove scipy-1.11.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Remove pytz-2023.3.post1-py2.py3-none-any.whl
# Remove nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl
# Remove nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl
# Remove contourpy-1.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl
# Remove networkx-3.2.1-py3-none-any.whl
# Remove kiwisolver-1.4.5-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl
# ...

# %%
# !rm -rf sennet-segmentation
